# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
d = pd.read_csv('/Volumes/FSL/data_bkup.csv').iloc[30:, :]
d
# Out:
#                        datetime  temperature_h  temperature_p    humidity  \
# 30   2022-04-04 13:10:35.714558      24.085251      23.945833   48.086014
# 31   2022-04-04 13:10:37.763239      24.191572      23.943750   47.798145
# 32   2022-04-04 13:10:39.812213      24.049809      23.950001   47.630714
# 33   2022-04-04 13:10:41.860997      24.120691      23.958334   45.621525
# 34   2022-04-04 13:10:43.909609      24.138411      23.956249   47.284100
# ..                          ...            ...            ...         ...
# 340  2022-04-04 13:21:10.367414      15.703545      16.072916  123.606834
# 341  2022-04-04 13:21:12.410898      15.845307      16.091667  123.627403
# 342  2022-04-04 13:21:14.458374      15.792147      16.118750  123.618584
# 343  2022-04-04 13:21:16.493899      15.809867      16.139584  123.621529
# 344  2022-04-04 13:21:18.540024      15.845307      16.166666  123.627403
#
#         pressure  orient_roll  orient_pitch  orient_yaw   accel_x   accel_y  \
# ...

# %%
fig, ax = plt.subplots(5, 1, figsize=(20, 20))

sns.lineplot(data=d[['datetime', 'temperature_h', 'temperature_p']], palette="tab10", linewidth=2.5, ax=ax[0])
sns.lineplot(data=d[['datetime', 'humidity']], palette="tab10", linewidth=2.5, ax=ax[1])
sns.lineplot(data=d[['datetime', 'pressure']], palette="tab10", linewidth=2.5, ax=ax[2])
sns.lineplot(data=d[['datetime', 'orient_roll', 'orient_pitch', 'orient_yaw']], palette="tab10", linewidth=2.5, ax=ax[3])
sns.lineplot(data=d[['datetime', 'accel_x', 'accel_y', 'accel_z']], palette="tab10", linewidth=2.5, ax=ax[4])
# Out:
# <AxesSubplot:>
